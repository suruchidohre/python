# %% [markdown]
# 1. What is Object-Oriented Programming (OOP) ?
#  a programming paradigm that organizes software design arond objects, ehich are data structures containing both data (attributes) and code (methods) that operate on that data promoting code reusability and modularity
#
# 2. what is a class in OOP ?
#
#   a blueprint or template creating objects , defining their attributes (data) and behaviors (methods)
#
# 3. What is an object in OOP ?
#
# a fundamental unit that encapsulates data (attributes or propreties) and the operate on that data representing a real-world entity or concept within a proggram
#
# 4. What is the difference between abstraction and encapsulation
#
#   abstraction focuses on presenting only essential details and hiding complex implementation , white encapsulation bundles data and methods t
#   into a unit restricting direct access and promoting controlled access through methods
#
# 5. What are dunder methods in Python
#
#   in python a "dunde"r or "magic"method is a method that has double underscores before and after its name
#
# 6. Explain the concept of inheritance in OOPH
#
#   a mechanism where a new class (sub- class or derived class ) inherits properties and behaviors form an existing class (suuuperclass or base class) promoting code reuuse and hierarchical relationships
#
# 7. What is polymorphism in OOP
#
#   allows a specific rotine to use variables of different types at differnt times
#
# 8 . How is encapsulation achieved in Python
#
#  encapsulation is achieved by declaring a class data members and methods as either private oe protecteds
#
# 9. What is a constructor in Python
#
# in python a constructor is a special method called when an object is created its purpose is to assignvalues to the data members within tha class when an aoject is initialized the name of the constructor method is always
#
#  10. What are class and static methods in Python
#
#  a class method is itself ( not on instance ), accessed  via the class name and typically used for creating new instances or method belongs to the class but is not bound to either the class or an instance and is used for utillty function that don't require  access to class or instance state
#
# 11. What is method overloading in Python
#
# theability to define multiple methods of the same name but with different parameters in many object oriented programming languages
#
# 12. What is method overriding in OOP
#
# a language featre that allows a subclass or child class to provide a specific  implementation of a method that is already provided by one of its superclasses or parent classes
#
# 13. What is a property decorator in Python
#
# a decorator feature in python wraps in a function appends several fnctionalities to existing code and then returns it
#
# 14. Why is polymorphism important in OOP+
#
# it allows  object of different classes to be treated as objects of a common type enabling code reuusability flexibility and maintainabillity
#
# 15.What is an abstract class in Python
#
# a blueprint for other classes designed to be subclassed but not instantiated directly containing abstract methods (methods without implementation ) that subclasses must implement
#
# 16. What are the advantages of OOP
#
# improved code organization through encapsulation reusability via inheritance ,flexibility with polymorphism and simplification of complex systems through abstraction leading to moduular maintainable and scalable software
#
# 17. What is the difference between a class variable and an instance variable
#
# a class variable (also known as a static variable is shared by all instances (object) of a class while an instance variable is unique to each instance
#
# 18.  What is multiple inheritance in Python
#
#  allows a class to inherit attributed and methods from more than one parent class combining fnctionalities from differnt base classes into a single derived class
#
# 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python
#
# this ensures that objects have meaningful string representations for both and developers
#
# 20. What is the significance of the ‘super()’ function in Python
#
# allows access to methods and properties of a parent or superclass from a child or subclass
#
# 21. What is the significance of the __del__ method in Python
#
#  the del statement is used to delete objects variable list elements or attributes of objects
#
# 22. What is the difference between @staticmethod and @classmethod in Python
#
# a class method takes cls as the first parameter white a static method needs on specific parametes
#
# 23. How does polymorphism work in Python with inheritance
#
# lets objects of diverse type share the same interface empowering method to be executed unexpectedly based on the object type
#
# 24. What is method chaining in Python OOP
#
# calling multiple methods sequentially on the same object in a sinle expression
#
# 25. What is the purpose of the __call__ method in Python?
#
#    the goal of_call _() is to turn your instances into callable objects
